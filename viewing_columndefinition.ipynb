# %%
# !pip install sqlalchemy==1.3.9
# !pip install ibm_db_sa

# %%
# %load_ext sql

# %%
# %sql ibm_db_sa://mxl88226:ncm%2B1bzvxn4fljb3@dashdb-txn-sbox-yp-lon02-02.services.eu-gb.bluemix.net:50000/BLUDB
# Out:
# 'Connected: mxl88226@BLUDB'

# %%
# %sql select TABSCHEMA, TABNAME, CREATE_TIME from SYSCAT.TABLES \
      where TABSCHEMA not in ('SYSIBM', 'SYSCAT', 'SYSSTAT', 'SYSIBMADM', 'SYSTOOLS', 'SYSPUBLIC')
# Out:
#  * ibm_db_sa://mxl88226:***@dashdb-txn-sbox-yp-lon02-02.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [('MXL88226', 'TEST', datetime.datetime(2021, 6, 6, 8, 51, 7, 841428)),
#  ('MXL88226', 'COUTRY', datetime.datetime(2021, 6, 6, 8, 51, 8, 80206)),
#  ('MXL88226', 'PETSALE', datetime.datetime(2021, 6, 6, 8, 59, 52, 955613)),
#  ('MXL88226', 'PET', datetime.datetime(2021, 6, 6, 8, 59, 53, 191630)),
#  ('MXL88226', 'EMPLOYEES', datetime.datetime(2021, 6, 6, 9, 3, 2, 85042)),
#  ('MXL88226', 'JOB_HISTORY', datetime.datetime(2021, 6, 6, 9, 3, 2, 616229)),
#  ('MXL88226', 'JOBS', datetime.datetime(2021, 6, 6, 9, 3, 3, 115831)),
#  ('MXL88226', 'DEPARTMENTS', datetime.datetime(2021, 6, 6, 9, 3, 3, 577430)),
#  ('MXL88226', 'LOCATIONS', datetime.datetime(2021, 6, 6, 9, 3, 4, 39460)),
#  ('MXL88226', 'PETRESCUE', datetime.datetime(2021, 6, 8, 3, 19, 7, 435718)),
#  ('MXL88226', 'INSTRUCTOR1', datetime.datetime(2021, 6, 10, 6, 28, 28, 144073)),
# ...

# %%
# %sql select count(*) from SCHOOLS;
# Out:
#  * ibm_db_sa://mxl88226:***@dashdb-txn-sbox-yp-lon02-02.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [(Decimal('566'),)]

# %%
# %sql select colname, tabname,  length from syscat.columns where tabname='SCHOOLS';
# Out:
#  * ibm_db_sa://mxl88226:***@dashdb-txn-sbox-yp-lon02-02.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [('School_ID', 'SCHOOLS', 4),
#  ('NAME_OF_SCHOOL', 'SCHOOLS', 65),
#  ('Elementary, Middle, or High School', 'SCHOOLS', 2),
#  ('Street_Address', 'SCHOOLS', 29),
#  ('Average_Teacher_Attendance', 'SCHOOLS', 6),
#  ('Individualized_Education_Program_Compliance_Rate', 'SCHOOLS', 7),
#  ('Pk_2_Literacy__', 'SCHOOLS', 4),
#  ('Pk_2_Math__', 'SCHOOLS', 4),
#  ('Gr3_5_Grade_Level_Math__', 'SCHOOLS', 4),
#  ('Gr3_5_Grade_Level_Read__', 'SCHOOLS', 4),
#  ('Gr3_5_Keep_Pace_Read__', 'SCHOOLS', 4),
#  ('Gr3_5_Keep_Pace_Math__', 'SCHOOLS', 4),
#  ('Gr6_8_Grade_Level_Math__', 'SCHOOLS', 4),
#  ('Gr6_8_Grade_Level_Read__', 'SCHOOLS', 4),
#  ('Gr6_8_Keep_Pace_Math_', 'SCHOOLS', 4),
#  ('Gr6_8_Keep_Pace_Read__', 'SCHOOLS', 4),
#  ('Gr_8_Explore_Math__', 'SCHOOLS', 4),
#  ('Gr_8_Explore_Read__', 'SCHOOLS', 4),
#  ('ISAT_Exceeding_Math__', 'SCHOOLS', 5),
# ...
